# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_parquet(r'D:\daneshkar\pandas-numpy-matplotlib\x\final_datasets\raw_match\away_team_all_days.parquet')
df
# Out:
#        match_id                name                   slug gender  user_count  \
# 0      11998445  Auger-Aliassime F.  auger-aliassime-felix      M     23318.0
# 1      11998446          Cobolli F.         flavio-cobolli      M      5995.0
# 2      11998447         Martínez P.         martinez-pedro      M      2621.0
# 3      11998448           Muller A.       muller-alexandre      M      2443.0
# 4      11998449            Mayot H.           mayot-harold      M      1492.0
# ...         ...                 ...                    ...    ...         ...
# 59251  12213482                None                   None   None         NaN
# 59252  12213483                None                   None   None         NaN
# 59253  12213484                None                   None   None         NaN
# 59254  12213486                None                   None   None         NaN
# 59255  12213803                None                   None   None         NaN
#
# ...

# %%
hand = df['plays']
hand
# Out:
# 0        right-handed
# 1        right-handed
# 2        right-handed
# 3        right-handed
# 4        right-handed
#              ...
# 59251            None
# 59252            None
# 59253            None
# 59254            None
# 59255            None
# Name: plays, Length: 59256, dtype: object

# %%
hand.dropna()
# Out:
# 0        right-handed
# 1        right-handed
# 2        right-handed
# 3        right-handed
# 4        right-handed
#              ...
# 58497    right-handed
# 58500    right-handed
# 58501    right-handed
# 58502    right-handed
# 58503    right-handed
# Name: plays, Length: 11959, dtype: object

# %%
hand.value_counts()
# Out:
# plays
# right-handed    10494
# left-handed      1465
# Name: count, dtype: int64

# %%
counts = hand.value_counts()
plt.bar(counts.index, counts.values, color=['skyblue', 'lightcoral'])
plt.xlabel('Hand')
plt.ylabel('Count')
plt.title('Distribution of Playing Hand')
plt.show()
