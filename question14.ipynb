# %%
import pandas as pd

# %%
df = pd.read_parquet(r'D:\daneshkar\pandas-numpy-matplotlib\x\final_datasets\raw_match\tournament_all_days.parquet')
df
# Out:
#        match_id  tournament_id                              tournament_name  \
# 0      11974053          70826                                   Qualifiers
# 1      11974066          70826                                   Qualifiers
# 2      11998445         126168                          Montpellier, France
# 3      11998446         126168                          Montpellier, France
# 4      11998447         126168                          Montpellier, France
# ...         ...            ...                                          ...
# 35666  12213482         128420  Hammamet, Singles Qualifying, M-ITF-TUN-24A
# 35667  12213483         128420  Hammamet, Singles Qualifying, M-ITF-TUN-24A
# 35668  12213484         128420  Hammamet, Singles Qualifying, M-ITF-TUN-24A
# 35669  12213486         128420  Hammamet, Singles Qualifying, M-ITF-TUN-24A
# 35670  12213803         128420  Hammamet, Singles Qualifying, M-ITF-TUN-24A
#
# ...

# %%
surface = df['ground_type']
surface
# Out:
# 0                    None
# 1                    None
# 2        Hardcourt indoor
# 3        Hardcourt indoor
# 4        Hardcourt indoor
#                ...
# 35666            Red clay
# 35667            Red clay
# 35668            Red clay
# 35669            Red clay
# 35670            Red clay
# Name: ground_type, Length: 35671, dtype: object

# %%
pure_surface = surface.dropna()
pure_surface
# Out:
# 2        Hardcourt indoor
# 3        Hardcourt indoor
# 4        Hardcourt indoor
# 5        Hardcourt indoor
# 6        Hardcourt indoor
#                ...
# 35666            Red clay
# 35667            Red clay
# 35668            Red clay
# 35669            Red clay
# 35670            Red clay
# Name: ground_type, Length: 35109, dtype: object

# %%
pure_surface.value_counts().sort_values(ascending= False)
# Out:
# ground_type
# Hardcourt outdoor    16959
# Red clay             11856
# Hardcourt indoor      4741
# Red clay indoor        512
# Grass                  509
# Carpet indoor          276
# Synthetic outdoor      226
# Green clay              30
# Name: count, dtype: int64
